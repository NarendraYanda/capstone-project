# %%
# !pip install pymupdf==1.18.19
# Out:
# Collecting pymupdf==1.18.19
#   Downloading PyMuPDF-1.18.19-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.1 kB)
# Downloading PyMuPDF-1.18.19-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 22.0 MB/s eta 0:00:00
# Installing collected packages: pymupdf
#   Attempting uninstall: pymupdf
#     Found existing installation: PyMuPDF 1.24.10
#     Uninstalling PyMuPDF-1.24.10:
#       Successfully uninstalled PyMuPDF-1.24.10
# Successfully installed pymupdf-1.18.19

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 2: Install Required Libraries
# !apt-get install tesseract-ocr
# !pip install pytesseract pdfplumber tabula-py

# Step 3: Import Libraries
import os
import re
import tabula
import pdfplumber
import pytesseract
from PIL import Image
import io
import pandas as pd
import spacy
import nltk
import string
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk import pos_tag

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

# Load Spacy model for Named Entity Recognition
nlp = spacy.load('en_core_web_sm')

# Function for text normalization
def text_normalization(text):
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Function to lemmatize tokens
def lemmatize_tokens(tokens):
    lemmatizer = WordNetLemmatizer()
    pos_tagged = pos_tag(tokens)
    lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(tag)) for word, tag in pos_tagged]
    return lemmatized_words

# Function to get WordNet POS tags
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Function for Named Entity Recognition (NER) using Spacy
def named_entity_recognition(text):
    doc = nlp(text)
    entities = [(entity.text, entity.label_) for entity in doc.ents]
    return entities

# Function to remove stopwords
def remove_stopwords(words):
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    return filtered_words

# Function to extract tables using Tabula-py and capture context around the table
def extract_tables_and_context(pdf_path, page_text, page_num, previous_page_text=None, lines_above=3, lines_below=3):
    tables = tabula.read_pdf(pdf_path, pages=page_num, multiple_tables=True)
    table_list = []
    all_lines = page_text.splitlines()

    if tables:
        for i, table in enumerate(tables):
            # Capture context above: If table is near the top of the page, look at the previous page's content
            if i == 0 and previous_page_text:
                previous_page_lines = previous_page_text.splitlines()
                context_above = "\n".join(previous_page_lines[-lines_above:])  # Get lines from the previous page
            else:
                context_above = "\n".join(all_lines[max(0, i - lines_above):i])

            # Capture context below
            context_below = "\n".join(all_lines[i + len(table):i + len(table) + lines_below])

            table_list.append({
                "table_number": i + 1,
                "table_data": table,
                "context_above": context_above,
                "context_below": context_below
            })
    return table_list

# Function to extract PDF content with OCR and tables with context
def extract_pdf_content_with_ocr(pdf_path, lines_above=3, lines_below=3):
    full_text = ""
    table_context_data = []
    previous_page_text = None

    with pdfplumber.open(pdf_path) as pdf:
        for page_num, page in enumerate(pdf.pages):
            print(f"Processing Page {page_num + 1} of {pdf_path}")
            page_text = page.extract_text()

            if page_text:
                full_text += page_text + "\n\n"

                # Extract tables and context from this page
                tables_with_context = extract_tables_and_context(pdf_path, page_text, page_num + 1, previous_page_text, lines_above, lines_below)
                table_context_data.append({
                    "page_number": page_num + 1,
                    "tables": tables_with_context
                })

                previous_page_text = page_text  # Store the current page's text for context on the next page
            else:
                print(f"Using OCR for Page {page_num + 1}")
                page_image = page.to_image()
                image_bytes = page_image.original
                img = Image.open(io.BytesIO(image_bytes))
                ocr_text = pytesseract.image_to_string(img)
                full_text += ocr_text + "\n\n"

    return full_text, table_context_data

# Function to process PDF files and extract tables with context
def process_files(pdf_directory):
    file_names = [os.path.splitext(f)[0] for f in os.listdir(pdf_directory) if f.endswith('.pdf')]
    all_preprocessed_data = []

    for file_name in file_names:
        pdf_path = os.path.join(pdf_directory, file_name + ".pdf")

        # Extract content from PDF using OCR and Tabula
        pdf_content, table_context_data = extract_pdf_content_with_ocr(pdf_path)

        # Pre-process the content
        normalized_text = text_normalization(pdf_content)
        words = word_tokenize(normalized_text)
        words = remove_stopwords(words)
        lemmatized_words = lemmatize_tokens(words)
        named_entities = named_entity_recognition(normalized_text)

        # Store the pre-processed data
        all_preprocessed_data.append({
            "file_name": file_name,
            "normalized_text": normalized_text,
            "lemmatized_words": list(lemmatized_words),
            "named_entities": named_entities,
            "table_context_data": table_context_data  # Include tables with their context
        })

    return all_preprocessed_data

# Specify directories
pdf_directory = "/content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF"

# Process all files
all_preprocessed_data = process_files(pdf_directory)

# Print all preprocessed data
for data in all_preprocessed_data:
    print(f"\nFile: {data['file_name']}")
    print(f"Normalized Text:\n{data['normalized_text'][:500]}")
    print(f"Lemmatized Words:\n{data['lemmatized_words'][:20]}")
    print(f"Named Entities:\n{data['named_entities']}")
    for context_data in data['table_context_data']:
        print(f"Page {context_data['page_number']}:")
        for table in context_data['tables']:
            print(f"Table {table['table_number']}:\n{table['table_data']}")
            print(f"Context Above:\n{table['context_above']}")
            print(f"Context Below:\n{table['context_below']}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.13)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (0.11.4)
# Requirement already satisfied: tabula-py in /usr/local/lib/python3.10/dist-packages (2.9.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Requirement already satisfied: pdfminer.six==20231228 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (43.0.0)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from tabula-py) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tabula-py) (1.26.4)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Processing Page 1 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 2 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 3 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 4 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 5 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 6 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 7 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 8 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 9 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 10 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 11 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 12 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 13 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 14 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 15 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 16 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 17 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 18 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 19 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 20 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 21 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 22 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 23 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 24 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 25 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 26 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 27 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 28 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 29 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 30 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 31 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 32 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 33 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 34 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 35 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 36 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 37 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 38 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 39 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
# Processing Page 40 of /content/drive/MyDrive/AIML/Capstone-Project/data/LimitedData/PDF/ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement.pdf
#
# File: ArmstrongFlooringInc_20190107_8-K_EX-10.2_11471795_EX-10.2_Intellectual Property Agreement
# Normalized Text:
# exhibit execution version intellectual property agreement this intellectual property agreement this “agreement” dated as of december the “effective date” is entered into by and between armstrong flooring inc a delaware corporation “seller” and afi licensing llc a delaware limited liability company “licensing” and together with seller “arizona” and ahf holding inc formerly known as tarzan holdco inc a delaware corporation “buyer” and armstrong hardwood flooring company a tennessee corporation the
# Lemmatized Words:
# ['exhibit', 'execution', 'version', 'intellectual', 'property', 'agreement', 'intellectual', 'property', 'agreement', '“', 'agreement', '”', 'date', 'december', '“', 'effective', 'date', '”', 'enter', 'armstrong']
# Named Entities:
# [('december', 'DATE'), ('arizona', 'GPE'), ('ahf holding inc formerly known', 'ORG'), ('holdco inc', 'ORG'), ('armstrong hardwood', 'PERSON'), ('arizona', 'GPE'), ('november', 'DATE'), ('wood products inc', 'ORG'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('the five years', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('the five years', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('the five years', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('months', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('u v', 'PERSON'), ('flooring inc k', 'ORG'), ('eighteen months', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('third', 'ORDINAL'), ('arizona', 'GPE'), ('world industries inc awi', 'ORG'), ('armstrong flooring inc', 'ORG'), ('april', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('third', 'ORDINAL'), ('third', 'ORDINAL'), ('third', 'ORDINAL'), ('third', 'ORDINAL'), ('third', 'ORDINAL'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('fortyfive days', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('thirty days', 'DATE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('the nonassigning party', 'ORG'), ('third', 'ORDINAL'), ('the next business day', 'DATE'), ('flooring inc k', 'ORG'), ('american', 'NORP'), ('lexington avenue', 'PERSON'), ('richard hoffman', 'PERSON'), ('baker botts', 'PERSON'), ('pennsylvania', 'GPE'), ('washington', 'GPE'), ('brendan', 'PERSON'), ('arizona', 'GPE'), ('christopher s parisi', 'PERSON'), ('new york', 'GPE'), ('eric l cochran', 'PERSON'), ('daniels', 'PERSON'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('arizona', 'GPE'), ('delaware', 'GPE'), ('castle county', 'GPE'), ('delaware', 'GPE'), ('castle county', 'GPE'), ('first', 'ORDINAL'), ('s christina geerlof', 'PERSON'), ('christina geerlof title', 'PERSON'), ('ahf holding inc formerly known', 'ORG'), ('tarzan holdco inc by', 'ORG'), ('s stanley edme name', 'ORG'), ('stanley edme title', 'PERSON'), ('ar ...
# Page 1:
# Page 2:
# Page 3:
# Page 4:
# Page 5:
# Page 6:
# Page 7:
# Page 8:
# Page 9:
# Page 10:
# Page 11:
# Page 12:
# Page 13:
# Page 14:
# Page 15:
# Page 16:
# Table 1:
#                          bruce.info  10-Aug-2019  AFI
# 0                        bruce.porn  28-Apr-2019  AFI
# 1                         bruce.xxx  01-Dec-2021  AFI
# 2                  brucebuilder.com  02-Mar-2019  AFI
# 3               brucecontractor.com  02-Mar-2019  AFI
# 4                   brucedealer.com  02-Mar-2019  AFI
# 5              brucedistributor.com  02-Mar-2019  AFI
# 6                   brucefloors.com  04-Aug-2019  AFI
# 7           brucehardwoodfloors.com  11-Apr-2019  AFI
# 8                     brucehome.com  02-Mar-2019  AFI
# 9                 brucelaminate.com  30-Dec-2018  AFI
# 10               bruceremodeler.com  02-Mar-2019  AFI
# 11                bruceretailer.com  02-Mar-2019  AFI
# 12                   brucesucks.com  25-Oct-2018  AFI
# 13                  brucesucks.info  22-Sep-2019  AFI
# 14       capellaflooringcompany.com  12-Nov-2018  AFI
# 15                capellafloors.com  27-Oct-2018  AFI
# 16           forestglenhardwood.com  13-Sep-2019  AFI
# 17         handscraped-hardwood.com  13-Apr-2019  AFI
# 18  handscrapedhardwoodflooring.com  13-Sep-2019  AFI
# 19         handscrapedwoodfloor.com  05-Sep-2019  AFI
# 20      handscrapehardwoodfloor.com  05-Sep-2019  AFI
# 21   handscrapehardwoodflooring.com  05-Sep-2019  AFI
# 22     handscrapehardwoodfloors.com  05-Sep-2019  AFI
# 23          handscrapewoodfloor.com  05-Sep-2019  AFI
# 24       handscrapewoodflooring.com  05-Sep-2019  AFI
# 25         handscrapewoodfloors.com  05-Sep-2019  AFI
# 26           hardwood-flooring.asia  26-Mar-2019  AFI
# 27                       hartco.biz  18-Nov-2018  AFI
# 28                      hartco.info  10-Aug-2019  AFI
# 29            hartcodistributor.com  02-Mar-2019  AFI
# 30               hartcoflooring.com  24-May-2019  AFI
# Context Above:
# Title: Vice President
# [Signature Page to IP Agreement]
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# handscrapehardwoodflooring.com 05-Sep-2019 AFI
# handscrapehardwoodfloors.com 05-Sep-2019 AFI
# handscrapewoodfloor.com 05-Sep-2019 AFI
# Page 17:
# Page 18:
# Page 19:
# Table 1:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0         NaN        NaN       App.
# 1     Country        NaN     Status
# 2          US    Granted        NaN
# 3          AU    Granted        NaN
# 4          CN    Granted        NaN
# 5          DE    Granted        NaN
# 6          EP    Granted        NaN
# 7          FR    Granted        NaN
# 8          GB    Granted        NaN
# 9          US    Granted        NaN
# 10         US    Granted        NaN
# 11         US    Granted        NaN
# 12         US    Granted        NaN
# 13         US    Granted        NaN
# 14         AU    Granted        NaN
# 15         EP  Published        NaN
# 16         AU    Granted        NaN
# 17         CA    Granted        NaN
# 18         CN    Granted        NaN
# 19         EP  Published        NaN
# 20         US    Granted        NaN
# 21         AU    Granted        NaN
# 22         CA    Granted        NaN
# 23         CN    Granted        NaN
# 24         US    Granted        NaN
# 25         CN    Granted        NaN
# 26         EP    Granted        NaN
# 27         US    Granted        NaN
# 28         AU    Granted        NaN
# 29         AU    Granted        NaN
# 30         CN    Granted        NaN
# 31         AU    Granted        NaN
# 32         CA    Granted        NaN
# 33         CN  Published        NaN
# 34         AU    Pending        NaN
# 35         CN  Published        NaN
#
#    Schedule 1.1(e) – Arizona Assigned Patents        Unnamed: 3  Unnamed: 4
# 0                                         NaN               NaN         NaN
# 1                     App. Number Filing Date     Patent Number  Issue Date
# 2                        10/459,977 12-Jun-03           7381474    3-Jun-08
# 3                        2004304906 22-Nov-04        2004304906   28-Oct-10
# 4                      200480039516 22-Nov-04  ZL200480039516.1    2-Jan-13
# 5                     6020040309575 22-Nov-04           1944158   11-Feb-17
# 6                         8007063.4 22-Nov-04           1944158    5-Jan-11
# 7                         8007063.4 22-Nov-04           1944158    5-Jan-11
# 8                         8007063.4 22-Nov-04           1944158    5-Jan-11
# 9                         10/727,749 4-Dec-03         7,261,947   28-Aug-07
# 10                       11/901,361 17-Sep-07         8,287,971   16-Oct-12
# 11                       13/611,028 12-Sep-12         8,399,075   19-Mar-13
# 12                       12/825,448 29-Jun-10           8801505   12-Aug-14
# 13                       14/458,103 12-Aug-14        10,072,427   11-Sep-18
# 14                       2014240948 28-Mar-14        2014240948   20-Oct-16
# 15                       14722915.7 28-Mar-14               NaN         NaN
# 16                       2013246000 10-Apr-13        2013246000   26-Nov-15
# 17                        2,869,667 10-Apr-13           2869667   19-Dec-17
# 18                     201380018751 10-Apr-13           2512525    9-Jun-17
# 19                       13718698.7 10-Apr-13               NaN         NaN
# 20                       13/442,960 10-Apr-13           9434087    6-Sep-16
# 21                       2013246002 10-Apr-13        2013246002   17-Dec-15
# 22                        2,869,752 10-Apr-13           2869752    3-Jan-17
# 23                     201380018754 10-Apr-13         104245258    3-May-17
# 24                       13/442,966 10-Apr-12         9,108,335   18-Aug-15
# 25                     201410046641 10-Feb-14         103978829   12-Apr-17
# 26                       14154551.7 10-Feb-14         EP2764965   21-Sep-16
# 27                       14/176,299 10-Feb-14           9701040   11-Jul-17
# 28                       2014240951 28-Mar-14        2014240951   30-Jun-16
# 29                       2013270463 10-Dec-13        2013270463   26-Nov-15
# 30                     201310674310 11-Dec-13         103866947    4-Jan-17
# 31                       2014274549 10-Dec-14        2014274549   15-Oct-15
# 32                         2,873,571 8-Dec-14           2873571   27-Mar-18
# 33                     201407560485 10-Dec-14               NaN         NaN
# 34                        2016287834 5-Jul-16               NaN         NaN
# 35                     2016800338922 5-Jul-16               NaN         NaN
# Context Above:
# wwwhartco.com 17-Jan-2019 AFI
# wwwrobbins.com 17-Jan-2019 AFI
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# CN Published 2016800338922 5-Jul-16
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 20:
# Table 1:
#    Unnamed: 0 Unnamed: 1    App.         Unnamed: 2   Unnamed: 3  \
# 0     Country        NaN  Status        App. Number  Filing Date
# 1          EP  Published     NaN         16818951.2     5-Jul-16
# 2          TW  Published     NaN        20160120286    28-Jun-16
# 3          WO  Published     NaN     PCT/US16/40942     5-Jul-16
# 4          CN  Published     NaN       201510954585    17-Dec-15
# 5          EP  Published     NaN         15201544.2    21-Dec-15
# 6          US  Published     NaN         14/970,662    16-Dec-15
# 7          AU    Pending     NaN         2016380976    20-Dec-16
# 8          CN  Published     NaN        20168078711    20-Dec-16
# 9          EP    Pending     NaN           16882368    20-Dec-16
# 10         US  Published     NaN         14/980,263    28-Dec-15
# 11         WO  Published     NaN  PCT/US2016/067690    20-Dec-16
# 12         AU    Pending     NaN         2016380975    20-Dec-16
# 13         CN  Published     NaN       201680078712    20-Dec-16
# 14         EP    Pending     NaN           16882368    20-Dec-16
# 15         US  Published     NaN         14/980,313    28-Dec-15
# 16         WO  Published     NaN  PCT/US2016/067688    20-Dec-16
# 17         WO  Published     NaN  PCT/US2017/055068     5-Oct-17
# 18         US  Published     NaN           15902327    22-Feb-18
# 19         WO  Published     NaN     PCT/US18/19186    22-Feb-18
# 20         US    Granted     NaN         09/478,016     5-Jan-00
# 21         US    Granted     NaN         11/390,679    28-Mar-06
# 22         US    Granted     NaN         09/175,661    20-Oct-98
# 23         US    Granted     NaN         09/303,176    30-Apr-99
# 24         US    Granted     NaN         09/241,878     2-Feb-99
# 25         US    Pending     NaN          62/611953    29-Dec-17
# 26         US    Expired     NaN         62/404,413     5-Oct-16
# 27         US    Expired     NaN         62/462,609    23/Feb-17
# 28         US  Abandoned     NaN         09/903,549    13-Jul-01
# 29         US  Abandoned     NaN         14/828,598    18-Aug-15
# 30         US    Expired     NaN         62/187,925     2-Jul-15
# 31         US    Granted     NaN         12/425,560    17-Apr-09
# 32         US    Granted     NaN         13/741,770    15-Jan-13
# 33         AU    Granted     NaN         2014274559    10-Dec-14
# 34         EP  Published     NaN         14199378.2    19-Dec-14
# 35         CN  Published     NaN      2015109813242    23-Dec-15
# 36         EP  Published     NaN         15202406.3    23-Dec-15
# 37         US    Granted     NaN         14/580,347    23-Dec-14
#
#        Unnamed: 4  Unnamed: 5
# 0   Patent Number  Issue Date
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# 5             NaN         NaN
# 6             NaN         NaN
# 7             NaN         NaN
# 8             NaN         NaN
# 9             NaN         NaN
# 10            NaN         NaN
# 11            NaN         NaN
# 12            NaN         NaN
# 13            NaN         NaN
# 14            NaN         NaN
# 15            NaN         NaN
# 16            NaN         NaN
# 17            NaN         NaN
# 18            NaN         NaN
# 19            NaN         NaN
# 20        6164351   26-Dec-00
# 21        7537841   26-May-09
# 22        6148884   21-Nov-00
# 23        6156402    5-Dec-00
# 24        6194078   27-Feb-01
# 25            NaN         NaN
# 26            NaN         NaN
# 27            NaN         NaN
# 28            NaN         NaN
# 29            NaN         NaN
# 30            NaN         NaN
# 31      8,357,752   22-Jan-13
# 32      8,617,654   31-Dec-13
# 33     2014274559   24-Mar-16
# 34            NaN         NaN
# 35            NaN         NaN
# 36            NaN         NaN
# 37      9,567,755   14-Feb-17
# Context Above:
# AU Pending 2016287834 5-Jul-16
# CN Published 2016800338922 5-Jul-16
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# US Granted 14/580,347 23-Dec-14 9,567,755 14-Feb-17
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 21:
# Page 22:
# Table 1:
#   Unnamed: 0          Unnamed: 1  \
# 0        NaN                 NaN
# 1    Country           Trademark
# 2         US     AMERICAN SCRAPE
# 3         CA  ARTISAN COLLECTIVE
# 4         US  ARTISAN COLLECTIVE
# 5         CA    ARTISTIC TIMBERS
# 6         US    ARTISTIC TIMBERS
# 7         US           BIRCH RUN
# 8         CA           BIRCH RUN
# 9         US       BRISTOL TRAIL
#
#   Schedule 1.1(f) – Arizona Assigned Trademarks  Unnamed: 2 Unnamed: 3  \
# 0                                          App.         NaN       Reg.
# 1                       Status Number App. Date         NaN     Number
# 2                  Registered 85616030 3-May-12         NaN    4481771
# 3                     Pending 1817435 10-Jan-17         NaN        NaN
# 4                                          CLTM         NaN        NaN
# 5                   Registered 1670991 2-Apr-14         NaN  TMA967273
# 6                                          CLTM         NaN        NaN
# 7               Registered 85/931,142 14-May-13         NaN  4,524,637
# 8                Registered 1,636,822 25-Jul-13         NaN  TMA905398
# 9                 Registered 86919986 25-Feb-16         NaN    5423957
#
#   Unnamed: 4
# 0        NaN
# 1  Reg. Date
# 2  11-Feb-14
# 3        NaN
# 4        NaN
# 5  31-Mar-17
# 6        NaN
# 7   6-May-14
# 8   4-Jun-15
# 9  13-Mar-18
# Context Above:
# Country Status App. Number Filing Date Patent Number Issue Date
# US Pending 15/724,391 5-Oct-17
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# US BRISTOL TRAIL Registered 86919986 25-Feb-16 5423957 13-Mar-18
# CA BRISTOL TRAIL Published 1769733 26-Feb-16
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 23:
# Table 1:
#   Unnamed: 0           Unnamed: 1  Unnamed: 2      App. Unnamed: 3     Reg.  \
# 0    Country            Trademark      Status    Number  App. Date   Number
# 1         US  BRUSHED IMPRESSIONS  Registered  86906683  12-Feb-16  5183009
# 2         CA  BRUSHED IMPRESSIONS   Published   1768050  16-Feb-16      NaN
# 3         CA              CAPELLA   Published   1789784   4-Jul-16      NaN
# 4         US               DUNDEE  Registered  86274578   7-May-14  4649247
# 5         US            EVERGUARD  Registered  86084365   7-Oct-13  4654066
# 6         US           FARMINGTON  Registered  86920079  25-Feb-16  5423958
# 7         CA           FARMINGTON   Published   1769729  26-Feb-16      NaN
# 8         US          FOREST GLEN  Registered  86084354   7-Oct-13  4633917
# 9         CA          FOREST GLEN  Registered   1769732  26-Feb-16   961263
#
#   Unnamed: 4
# 0  Reg. Date
# 1  11-Apr-17
# 2        NaN
# 3        NaN
# 4   2-Dec-14
# 5   9-Dec-14
# 6  13-Mar-18
# 7        NaN
# 8   4-Nov-14
# 9  27-Jan-17
# Context Above:
# US BRISTOL TRAIL Registered 86919986 25-Feb-16 5423957 13-Mar-18
# CA BRISTOL TRAIL Published 1769733 26-Feb-16
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# CA FOREST GLEN Registered 1769732 26-Feb-16 961263 27-Jan-17
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 24:
# Table 1:
#   Unnamed: 0        Unnamed: 1  Unnamed: 2 Unnamed: 3       App. Unnamed: 4  \
# 0    Country         Trademark         NaN     Status     Number  App. Date
# 1         CA   FORGED HERITAGE   Published        NaN  1,752,076  26-Oct-15
# 2         CA          Hydropel     Pending        NaN    1917541  30-Aug-18
# 3         US          Hydropel     Pending        NaN   88148020   9-Oct-18
# 4         US         LOCK&FOLD  Registered        NaN   76656450  13-Mar-06
# 5         US           MIDTOWN  Registered        NaN   85736605  24-Sep-12
# 6         US   MILLWORK SQUARE  Registered        NaN   86906649  12-Feb-16
# 7         CA   MILLWORK SQUARE   Published        NaN    1768051  16-Feb-16
# 8         CA  ORIGINAL RUSTICS   Published        NaN    1791791  18-Jul-16
#
#       Reg. Unnamed: 5
# 0   Number  Reg. Date
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4  3200208  23-Jan-07
# 5  4401628  10-Sep-13
# 6  5183008  11-Apr-17
# 7      NaN        NaN
# 8      NaN        NaN
# Context Above:
# US FOREST GLEN Registered 86084354 7-Oct-13 4633917 4-Nov-14
# CA FOREST GLEN Registered 1769732 26-Feb-16 961263 27-Jan-17
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# CA ORIGINAL RUSTICS Published 1791791 18-Jul-16
# US ORIGINAL RUSTICS CLTM
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 25:
# Page 26:
# Table 1:
#   Unnamed: 0             Unnamed: 1  Unnamed: 2      App. Unnamed: 3     Reg.  \
# 0    Country              Trademark      Status    Number  App. Date   Number
# 1         US       SIGNATURE SCRAPE  Registered  86920111  25-Feb-16  5187924
# 2         CA       SIGNATURE SCRAPE   Published   1769731  26-Feb-16      NaN
# 3         CA  SIGNATURE SOFT SCRAPE   Published   1769730  26-Feb-16      NaN
# 4         US            TimberBlock   Published  87839322  19-Mar-18      NaN
# 5         CA            TimberBlock     Pending   1889001  20-Mar-18      NaN
# 6         US          TIMBERBRUSHED  Registered  87105110  15-Jul-16  5267454
# 7         US             TIMBERCUTS  Registered  87295586  10-Jan-17  5371502
# 8         CA             TIMBERCUTS     Pending   1817434  10-Jan-17      NaN
# 9         US             TIMBERLAND  Registered  76496979  13-Mar-03  2923877
#
#   Unnamed: 4
# 0  Reg. Date
# 1  18-Apr-17
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6  15-Aug-17
# 7   2-Jan-18
# 8        NaN
# 9   1-Feb-05
# Context Above:
# US SDF Pending ‘87947440 4-Jun-18
# CA SDF Pending 1902212 1-Jun-18
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# US TIMBERLAND Registered 76496979 13-Mar-03 2923877 1-Feb-05
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 27:
# Table 1:
#   Unnamed: 0         Unnamed: 1  Unnamed: 2       App. Unnamed: 3     Reg.  \
# 0    Country          Trademark      Status     Number  App. Date   Number
# 1         CA     TRANQUIL WOODS   Published    1790828  11-Jul-16      NaN
# 2         US     TRANQUIL WOODS        CLTM        NaN        NaN      NaN
# 3         US             TruTop   Published   87870541  10-Apr-18      NaN
# 4         CA             TruTop     Pending    1892873  10-Apr-18      NaN
# 5         CA  VINTAGE FARMHOUSE   Published    1790827  11-Jul-16      NaN
# 6         US        WEAR MASTER  Registered  74/329383   9-Nov-92  1834641
# 7         CN        WEAR MASTER  Registered    4819937   5-Aug-05  4819937
# 8         CA         OPAL CREEK  Registered    1738695  23-Jul-15  1002365
# 9         US         OPAL CREEK  Registered       CLTM        NaN      NaN
#
#   Unnamed: 4
# 0  Reg. Date
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6   3-May-94
# 7        NaN
# 8  08-Aug-18
# 9        NaN
# Context Above:
# CA TIMBERCUTS Pending 1817434 10-Jan-17
# US TIMBERLAND Registered 76496979 13-Mar-03 2923877 1-Feb-05
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# US OPAL CREEK Registered CLTM
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 28:
# Page 29:
# Table 1:
#    Unnamed: 0            Unnamed: 1  \
# 0     COUNTRY               APP NO.
# 1          AU            2009241803
# 2          AU            2013231111
# 3          CN          200980120494
# 4          DE     60 2009 024 610.0
# 5          EP             9739191.6
# 6          EP            13192693.3
# 7          FR             9739191.6
# 8          GB             9739191.6
# 9          US            12/432,845
# 10         US            14/700,669
# 11         BE            10770074.2
# 12         DE  DE 60 2010 031 448.0
# 13         EP            10770074.2
# 14         FR            10770074.2
# 15         GB            10770074.2
# 16         NL            10770074.2
# 17         US            12/799,700
# 18         US            14/140,206
# 19         AU            2012286867
# 20         CN         2012800367594
# 21         DE            12751639.1
# 22         EP            12751639.1
# 23         GB            12751639.1
# 24         AU            2013222106
# 25         EP            13707792.1
# 26         US            14/380,432
# 27         AU            2013308554
# 28         CN          201380046030
# 29         EP            13770989.5
# 30         US            14/423,186
# 31         AU            2014207438
# 32         EP            14702412.9
# 33         US            14/760,080
# 34         AU            2014207441
# 35         CN         2014800055962
# 36         EP            14703007.6
#
#    Schedule 1.1(l) - Arizona Licensed Patents  Unnamed: 2
# 0                   FILING DATE PATENT NUMBER  ISSUE DATE
# 1                        30-Apr-09 2009241803   26-Sep-13
# 2                        19-Sep-13 2013231111    7-Jan-16
# 3                                   30-Apr-09         NaN
# 4                         30-Apr-09 2 286 018         NaN
# 5                           30-Apr-09 2286018   11-Jun-14
# 6                           30-Apr-09 2703461   31-Aug-16
# 7                         30-Apr-09 2 286 018   11-Jun-14
# 8                         30-Apr-09 2 286 018   11-Jun-14
# 9                         30-Apr-09 8,420,710   16-Apr-13
# 10                                  30-Apr-15         NaN
# 11                        29-Nov-11 2 424 911   23-Mar-16
# 12                        29-Nov-11 2 424 911   23-Mar-16
# 13                        29-Nov-11 2 424 911   23-Mar-16
# 14                        29-Nov-11 2 424 911   23-Mar-16
# 15                        29-Nov-11 2 424 911   23-Mar-16
# 16                        29-Nov-11 2 424 911   23-Mar-16
# 17                                  30-Apr-10         NaN
# 18                                  24-Dec-13         NaN
# 19                       26-Jul-12 2012286867    4-Feb-16
# 20                          26-Jul-12 2094039    1-Jun-16
# 21                        26-Jul-12 EP2736977   20-May-15
# 22                        26-Jul-12 EP2736977   20-May-15
# 23                        26-Jul-12 EP2736977   20-May-15
# 24                       25-Feb-13 2013222106   25-Feb-13
# 25                                  25-Feb-13         NaN
# 26                          22-Aug-14 9540825   10-Jan-17
# 27                       30-Aug-13 2013308554   28-Apr-16
# 28                           4-Mar-15 2789549   23-Jan-18
# 29                        30-Mar-15 EP2890749   16-May-18
# 30                                  23-Feb-15         NaN
# 31                        8-Jul-15 2014207438    9-Feb-17
# 32                                  14-Aug-15         NaN
# 33                                   9-Jul-15         NaN
# 34                        8-Jul-15 2014207441   10-Nov-16
# 35                          15-Jul-15 2581656   11-Aug-17
# 36                                  14-Aug-15         NaN
# Context Above:
# armstrongwoodproducts.com 19-Dec-
# 2018 AFI
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# EP 14703007.6 14-Aug-15
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 30:
# Table 1:
#    COUNTRY            APP NO. FILING DATE  PATENT NUMBER ISSUE DATE
# 0       US         14/760,060    9-Jul-15            NaN        NaN
# 1       AU         2015227440   16-Sep-15   2.015227e+09  30-Mar-17
# 2       CN      2015105859497   23-Dec-14   3.045520e+06  24-Aug-18
# 3       EP         15198373.1    8-Dec-15            NaN        NaN
# 4       US         14/580,312   23-Dec-14   9.650792e+06  16-May-17
# 5       EP            1151281   12-Jul-00   1.072659e+06  13-Oct-04
# 6       US         10/062,616   31-Jan-02   6.572932e+06   3-Jun-03
# 7       US         10/060,487   30-Jan-02   6.911263e+06  28-Jun-05
# 8       AU         2016243556    6-Nov-17            NaN        NaN
# 9       CN      2016800223098   16-Oct-17            NaN        NaN
# 10      EP         16719581.7   14-Nov-17            NaN        NaN
# 11      TW          105110285   31-Mar-16   6.243660e+05  21-May-18
# 12      US         14/678,163    3-Apr-15            NaN        NaN
# 13      WO     PCT/US16/24457   28-Mar-16            NaN        NaN
# 14      AU         2016243132    6-Nov-17            NaN        NaN
# 15      CN      2016800229978   20-Oct-17            NaN        NaN
# 16      EP           16718052   14-Nov-17            NaN        NaN
# 17      US           15564161    3-Oct-17            NaN        NaN
# 18      WO     PCT/US16/24462   28-Mar-16            NaN        NaN
# 19      US         62/142,611    3-Apr-15            NaN        NaN
# 20      AU         2016243552    6-Nov-17            NaN        NaN
# 21      CN      2016800226325   18-Oct-17            NaN        NaN
# 22      EP         16719580.9   14-Nov-17            NaN        NaN
# 23      US         14/678,183    3-Apr-15            NaN        NaN
# 24      WO     PCT/US16/24451   28-Mar-16            NaN        NaN
# 25      AU         2016357732   18-Apr-18            NaN        NaN
# 26      CN      2016800648806    7-May-18            NaN        NaN
# 27      EP         16866982.8   14-Jun-18            NaN        NaN
# 28      US           15776637   16-May-18            NaN        NaN
# 29      WO  PCT/US2016/062133   16-Nov-16            NaN        NaN
# 30      WO  PCT/US2017/055060    5-Oct-17            NaN        NaN
# 31      WO  PCT/US2017/055047    4-Oct-17            NaN        NaN
# 32      WO  PCT/US2017/055077    4-Oct-17            NaN        NaN
# 33      WO  PCT/US2017/055089    5-Oct-17            NaN        NaN
# 34      WO  PCT/US2017/055044    5-Oct-17            NaN        NaN
# 35      WO  PCT/US2017/055033    4-Oct-17            NaN        NaN
# 36      US         14/721,724   26-May-15   9.468314e+06  18-Oct-16
# Context Above:
# CN 2014800055962 15-Jul-15 2581656 11-Aug-17
# EP 14703007.6 14-Aug-15
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# US 14/721,724 26-May-15 9468314 18-Oct-16
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 31:
# Page 32:
# Table 1:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Schedule 1.1(s) - Company Licensed Patents  \
# 0        NaN        NaN       App.                                        NaN
# 1    Country        NaN     Status                    App. Number Filing Date
# 2         US    Granted        NaN                       12/425,560 17-Apr-09
# 3         US    Granted        NaN                       13/741,770 15-Jan-13
# 4         CN  Published        NaN                    2015109813242 23-Dec-15
# 5         EP  Published        NaN                       15202406.3 23-Dec-15
# 6         US    Granted        NaN                       14/580,347 23-Dec-14
# 7         US    Pending        NaN                        15/724,391 5-Oct-17
#
#       Unnamed: 3  Unnamed: 4
# 0            NaN         NaN
# 1  Patent Number  Issue Date
# 2      8,357,752   22-Jan-13
# 3      8,617,654   31-Dec-13
# 4            NaN         NaN
# 5            NaN         NaN
# 6      9,567,755   14-Feb-17
# 7            NaN         NaN
# Context Above:
# Schedule 1.1(m) – Arizona Licensed Trademarks
# ARMSTRONG
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Context Below:
# US Pending 15/724,391 5-Oct-17
# Source: ARMSTRONG FLOORING, INC., 8-K, 1/7/2019
# Page 33:
# Page 34:
# Page 35:
# Page 36:
# Page 37:
# Page 38:
# Page 39:
# Page 40:

# %%
# !jupyter nbconvert --to html Capstone_Week1_plus_suggestions.ipynb
# Out:
# [NbConvertApp] Converting notebook Capstone_Week1_plus_suggestions.ipynb to html
# [NbConvertApp] ERROR | Notebook JSON is invalid: Additional properties are not allowed ('metadata' was unexpected)
#
# Failed validating 'additionalProperties' in stream:
#
# On instance['cells'][1]['outputs'][0]:
# {'metadata': {'tags': None},
#  'name': 'stdout',
#  'output_type': 'stream',
#  'text': 'Drive already mounted at /content/drive; to attempt to forcibly '
#          '...'}
# [NbConvertApp] Writing 674441 bytes to Capstone_Week1_plus_suggestions.html
